# %%
import numpy as np
import pandas as pd
import pylab as plt
import matplotlib

# %%
matplotlib.rcParams['font.family'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# %%
gen_data = pd.read_csv('盈亏比.csv', index_col=0)

# %%
fig = plt.figure(figsize=(50, 10))
ax1 = fig.add_subplot(211)
i = 0
plt.title("gold_macd", fontdict={'fontsize': 20})
gen_data['gold_macd'].iloc[i:i+365].plot(ax=ax1, kind='bar', color='orangered')
gen_data['gold_dif'].iloc[i:i+365].plot(ax=ax1, kind='line', xticks=range(i, i+365, 30))
gen_data['gold_dea'].iloc[i:i+365].plot(ax=ax1, kind='line', xticks=range(i, i+365, 30))
ax1.set_xticklabels(labels=range(i, i+365, 30), rotation=0, fontsize=20)
for label in ax1.get_yticklabels():
    label.set_fontsize(20)
ax2 = fig.add_subplot(212)

gen_data['gold_macd'].iloc[1465:].plot(ax=ax2, kind='bar', color='orangered', xticks=range(i, i+365, 30))
ax2.plot(gen_data['gold_dif'].iloc[1465:].values, ls='-', label="gold_dif")
ax2.plot(gen_data['gold_dea'].iloc[1465:].values, ls='-', label="gold_dea")

for label in ax2.get_yticklabels():
    label.set_fontsize(20)
ax2.set_xticklabels(labels=range(i, i+365, 30), rotation=0, fontsize=20)
plt.legend(fontsize=20)

plt.savefig('第一年和最后一年的黄金macd图.png')
plt.show()

fig = plt.figure(figsize=(50, 10))
ax1 = fig.add_subplot(211)
i = 0
plt.title("bitcorn_macd", fontdict={'fontsize': 20})

gen_data['bit_macd'].iloc[i:i+365].plot(ax=ax1, kind='bar', color='purple')
gen_data['bit_dif'].iloc[i:i+365].plot(ax=ax1, kind='line', xticks=range(i, i+365, 30), color='blue')
gen_data['bit_dea'].iloc[i:i+365].plot(ax=ax1, kind='line', xticks=range(i, i+365, 30), color="green")
ax1.set_xticklabels(labels=range(i, i+365, 30), rotation=0, fontsize=20)
for label in ax1.get_yticklabels():
    label.set_fontsize(20)
ax2 = fig.add_subplot(212)

gen_data['bit_macd'].iloc[1465:].plot(ax=ax2, kind='bar', color='purple', xticks=range(i, i+365, 30))
ax2.plot(gen_data['bit_dif'].iloc[1465:].values, ls='-', label="gold_dif", color='blue')
ax2.plot(gen_data['bit_dea'].iloc[1465:].values, ls='-', label="gold_dea", color='green')

for label in ax2.get_yticklabels():
    label.set_fontsize(20)
ax2.set_xticklabels(labels=range(i, i+365, 30), rotation=0, fontsize=20)
plt.legend(fontsize=20)

plt.savefig('第一年和最后一年的比特币macd图.png')
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax1.set_title("Gold MA", fontdict={"fontsize":20})
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
gen_data[['USD (PM)', 'gold_ma5', 'gold_ma15']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['USD (PM)', 'gold_ma5', 'gold_ma15']].loc[1465:].plot(ax=ax2)
plt.savefig('第一年和最后一年黄金ma.png')
plt.show()
fig = plt.figure(figsize=(20, 10))
ax1.set_title("Bitcorn MA", fontdict={"fontsize":20})
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
gen_data[['Value', 'bit_ma5', 'bit_ma15']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['Value', 'bit_ma5', 'bit_ma15']].loc[1465:].plot(ax=ax2)
plt.savefig('第一年和最后一年比特币ma.png')

plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
ax1.set_title("Gold RSI", fontdict={"fontsize":20})
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['gold_rsi_15']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['gold_rsi_15']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年黄金rsi.png')
plt.show()

fig = plt.figure(figsize=(20, 10))
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
ax1.set_title("Bitcorn RSI", fontdict={"fontsize":20})
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['bit_rsi_5']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['bit_rsi_5']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年比特币rsi.png')
plt.show()

# %%
gen_data = pd.read_csv("general_table.csv")

# %%
fig = plt.figure(figsize=(20, 10))
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
ax1.set_title("Gold Quantile", fontdict={"fontsize":20})
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['gold_quantile']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['gold_quantile']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年黄金quantile.png')
plt.show()

fig = plt.figure(figsize=(20, 10))
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
ax1.set_title("Bitcorn Quantile", fontdict={"fontsize":20})
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['bit_quantile']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['bit_quantile']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年比特币quantile.png')
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax1.set_title("Gold Price", fontdict={"fontsize":20})
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['USD (PM)']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年黄金价格.png')
plt.show()

fig = plt.figure(figsize=(20, 10))
ax1.set_title("Bitcorn Price", fontdict={"fontsize":20})
ax1, ax2 = fig.add_subplot(211), fig.add_subplot(212)
# gen_data[['USD (PM)']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['Value']].loc[:365].plot(ax=ax1, xticks=range(0, 360, 30))
gen_data[['Value']].loc[1465:].plot(ax=ax2, color='purple')
plt.savefig('第一年和最后一年比特币价格.png')
plt.show()

# %%
gen_data['bit_growth_rate'].plot()
plt.title("bitcorn growth rate")
plt.savefig('比特币涨幅率.png')
plt.show()

gen_data['gold_growth_rate'].plot()
plt.title("gold growth rate")
plt.savefig("黄金涨幅率.png")
plt.show()

# %%
arima_data = pd.read_csv("arima.csv")

# %%
arima_data.columns
# Out:
# Index(['V1', 'Date', 'USDPM', 'Value', 'DealDay', '黄金涨幅', '比特币涨幅', '黄金15日均价',
#        '黄金15日乖离率', '比特币5日均价', '比特币5日乖离率', '当前黄金投资占比', '当前比特币投资占比', '黄金投资风险',
#        '比特币投资风险', '黄金持有份额', '比特币持有份额', '现金持有份额', '总资产', '总资产变化率', '当前黄金利润',
#        '当前比特币利润', '牛市', '黄金15日后预计份额', '预计黄金涨幅', '比特币5日后预计份额', '预计比特币涨幅',
#        '预计现金持有份额', '预计总资产', '预计总资产变化率', '黄金牛市', 'gold_cow', '比特币牛市', 'bt_cow',
#        '黄金购买风险', '比特币购买风险', '黄金预测spss_黄金涨幅_模型_1', '黄金残差spss_黄金涨幅_模型_1',
#        '黄金预测spss_比特币涨幅_模型_1', '黄金残差spss_比特币涨幅_模型_1'],
#       dtype='object')

# %%
tgd = pd.DataFrame()
tgd['gold_growth'] = arima_data['黄金涨幅']
tgd['gold_pred_growth']= arima_data['黄金预测spss_黄金涨幅_模型_1']

tgd.plot()
plt.legend()
plt.savefig('黄金涨幅spss.png')
plt.show()

tbd = pd.DataFrame()
tbd['bit_pred'] = arima_data['比特币涨幅']
tbd['bit_growth_pred'] = arima_data['黄金预测spss_比特币涨幅_模型_1']
tbd.plot()
plt.savefig('比特币涨幅spss.png')
plt.show()
